# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('test_data_clean_uak211.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        date  station_id test_type test_result  \
# 0           1  01/01/2017       456.0     OBDII        Pass
# 1           2  01/01/2017      1115.0     OBDII        Pass
# 2           3  01/01/2017      1109.0     OBDII        Pass
# 3           4  01/01/2017      1115.0     OBDII        Pass
# 4           5  01/01/2017      1115.0      Idle        Fail
#
#                  vin  model_year   vehicle_type vehicle_class  \
# 0  5N1AN08W97C530793      2007.0          Truck          LDT1
# 1  WBANB53537CP05224      2007.0  Passenger Car           LDV
# 2  JN8AZ28R49T111532      2009.0  Passenger Car          LDT1
# 3  1N6AA07C18N350248      2008.0          Truck          LDT1
# 4  1J4GZ88S5PC113745      1993.0  Passenger Car           LDV
#
#    gross_vehicle_weight_rating
# 0                       5400.0
# 1                       5026.0
# 2                       3848.0
# 3                       7200.0
# 4                       5500.0

# %% [markdown]
# ## 1. Prepare OBDII test only data
#     - filter out the OBDII data
#     - merge the OBDII data with verified csv (with price for further use)
#     - merge the OBDII data with station location (lat/long) for mapping

# %%
OBDII_data = data[data['test_type'] == 'OBDII']

# %%
OBDII_data = pd.DataFrame(OBDII_data.groupby(['station_id'])['test_result'].count()).reset_index()

# %%
OBDII_data.head()
# Out:
#    station_id  test_result
# 0         1.0         2099
# 1         2.0         1916
# 2        11.0          627
# 3        24.0         1515
# 4        28.0         1029

# %%
station_info = pd.read_csv('verified_avg_fee_by_station_jx.csv')
station_info.head()
# Out:
#    No.  Station Id Avg. Test Fees             Station Name  \
# 0  1.0         2.0            $25  KEN GARFF MERCEDES BENZ
# 1  2.0        24.0            $39   OLYMPUS HILLS SINCLAIR
# 2  3.0        28.0            $31            UNION SERVICE
# 3  4.0        38.0            $30   LARRY H. MILLER TOYOTA
# 4  5.0        46.0            $35         QUALITY TIRE CO.
#
#                    Address            City      ZIP   Phone Number Price Tax  \
# 0          575 SOUTH STATE  SALT LAKE CITY  84111.0   855-780-1053    25   0
# 1  3905 SOUTH WASATCH BLVD  SALT LAKE CITY  84124.0  801- 272-2081    39   0
# 2      997 EAST 7220 SOUTH         MIDVALE  84047.0   801-255-4122    Na  Na
# 3          5650 S STATE ST          MURRAY  84107.0   801-264-3850    30   0
# 4     1335 WEST 2100 SOUTH  SALT LAKE CITY  84119.0   801-972-1944    Na  Na
#
#   On the Spot Registration Registration/Sticker Fee   Service Type  \
# 0                       Na                       Na  TestAndRepair
# 1                       Na                       Na  TestAndRepair
# 2                       Na                       Na             Na
# 3                      Yes                        5  TestAndRepair
# 4                       Na                       Na             Na
#
#   Detailed Information
# 0                   Na
# 1                   Na
# 2                   Na
# 3                   Na
# 4                   Na

# %%
OBDII_data = pd.merge(OBDII_data, station_info, how='left', left_on ='station_id', right_on = 'Station Id')

# %%
OBDII_data.shape
# Out:
# (522, 16)

# %%
station_latlng = pd.read_csv('SLCo_station_latlong_v1_yc.csv')
station_latlng = station_latlng[['Station Id', 'Latitude', 'Longitude']]
station_latlng['Station Id'] = station_latlng['Station Id'].astype(int)
station_latlng.head()
# Out:
#    Station Id   Latitude   Longitude
# 0           2  40.756698 -111.887756
# 1          24  40.686708 -111.795525
# 2          28  40.619111 -111.862117
# 3          38  40.648415 -111.889550
# 4          46  40.725605 -111.929081

# %%
OBDII_data = pd.merge(OBDII_data, station_latlng, left_on = 'station_id', right_on = 'Station Id', how='right')
OBDII_data.shape
# Out:
# (435, 19)

# %%
OBDII_data.to_csv('mapping_OBDII_data_yc3420.csv')

# %% [markdown]
# ## 2. Prepare all test type
#     - merge all test data with verified csv (with price for further use)
#     - merge all test data with station location (lat/long) for mapping

# %%
All_data = pd.DataFrame(data.groupby(['station_id'])['test_result'].count()).reset_index()

# %%
All_data.head()
# Out:
#    station_id  test_result
# 0         1.0         2938
# 1         2.0         1961
# 2        11.0          797
# 3        24.0         1635
# 4        28.0         1167

# %%
All_data = pd.merge(All_data, station_info, how='left', left_on ='station_id', right_on = 'Station Id')

# %%
All_data = pd.merge(All_data, station_latlng, left_on = 'station_id', right_on = 'Station Id', how='right')

# %%
All_data.head()
# Out:
#    station_id  test_result  No.  Station Id_x Avg. Test Fees  \
# 0         2.0       1961.0  1.0           2.0            $25
# 1        24.0       1635.0  2.0          24.0            $39
# 2        28.0       1167.0  3.0          28.0            $31
# 3        38.0      11557.0  4.0          38.0            $30
# 4        46.0       4954.0  5.0          46.0            $35
#
#               Station Name                  Address            City      ZIP  \
# 0  KEN GARFF MERCEDES BENZ          575 SOUTH STATE  SALT LAKE CITY  84111.0
# 1   OLYMPUS HILLS SINCLAIR  3905 SOUTH WASATCH BLVD  SALT LAKE CITY  84124.0
# 2            UNION SERVICE      997 EAST 7220 SOUTH         MIDVALE  84047.0
# 3   LARRY H. MILLER TOYOTA          5650 S STATE ST          MURRAY  84107.0
# 4         QUALITY TIRE CO.     1335 WEST 2100 SOUTH  SALT LAKE CITY  84119.0
#
#     Phone Number Price Tax On the Spot Registration Registration/Sticker Fee  \
# 0   855-780-1053    25   0                       Na                       Na
# 1  801- 272-2081    39   0                       Na                       Na
# 2   801-255-4122    Na  Na                       Na                       Na
# 3   801-264-3850    30   0                      Yes                        5
# 4   801-972-1944    Na  Na                       Na                       Na
#
#     Service Type Detailed Information  Station Id_y   Latitude   Longitude
# 0  TestAndRepair                   Na             2  40.756698 -111.887756
# 1  TestAndRepair                   Na            24  40.686708 -111.795525
# 2             Na                   Na            28  40.619111 -111.862117
# 3  TestAndRepair                   Na            38  40.648415 -111.889550
# 4             Na                   Na            46  40.725605 -111.929081

# %%
All_data.to_csv('mapping_All_data_yc3420.csv')

# %% [markdown]
# # 3. Download and clean the population data

# %% [markdown]
# ### data source: American Fact Finder
# ### 2013-2017 American Community Survey 5-Year Estimates
# ### instruction link: https://gis.stackexchange.com/questions/9380/where-to-get-2010-census-block-data

# %%
SLCo_pop_all = pd.read_csv('aff_download/ACS_17_5YR_DP05_with_ann.csv')

# %%
SLCo_pop_all.head()
# Out:
#                  GEO.id      GEO.id2  \
# 0                    Id          Id2
# 1  1400000US49035100100  49035100100
# 2  1400000US49035100200  49035100200
# 3  1400000US49035100306  49035100306
# 4  1400000US49035100307  49035100307
#
#                               GEO.display-label  \
# 0                                     Geography
# 1     Census Tract 1001, Salt Lake County, Utah
# 2     Census Tract 1002, Salt Lake County, Utah
# 3  Census Tract 1003.06, Salt Lake County, Utah
# 4  Census Tract 1003.07, Salt Lake County, Utah
#
#                                   HC01_VC03  \
# 0  Estimate; SEX AND AGE - Total population
# 1                                      1690
# 2                                      1405
# 3                                      5219
# 4                                      5487
#
#                                          HC02_VC03  \
# 0  Margin of Error; SEX AND AGE - Total population
# 1                                              249
# 2                                              142
# 3                                              512
# 4                                              457
#
#                                  HC03_VC03  \
# 0  Percent; SEX AND AGE - Total population
# 1                                     1690
# 2                                     1405
# 3                                     5219
# 4                                     5487
#
#                                            HC04_VC03  \
# 0  Percent Margin of Error; SEX AND AGE - Total p...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          HC01_VC04  \
# 0  Estimate; SEX AND AGE - Total population - Male
# 1                                             1033
# 2                                              672
# 3                                             2519
# 4                                             2567
#
#                                            HC02_VC04  \
# 0  Margin of Error; SEX AND AGE - Total populatio...
# 1                                                202
# 2                                                 93
# 3                                                334
# 4                                                298
#
#                                         HC03_VC04  ...  \
# 0  Percent; SEX AND AGE - Total population - Male  ...
# 1                                            61.1  ...
# 2                                            47.8  ...
# 3                                            48.3  ...
# 4                                            46.8  ...
#
#                                           HC03_VC113  \
# 0  Percent; CITIZEN, VOTING AGE POPULATION - Citi...
# 1                                               1210
# 2                                               1132
# 3                                               2628
# 4                                               2485
#
#                                           HC04_VC113  \
# 0  Percent Margin of Error; CITIZEN, VOTING AGE P...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           HC01_VC114  \
# 0  Estimate; CITIZEN, VOTING AGE POPULATION - Cit...
# 1                                                723
# 2                                                573
# 3                                               1434
# 4                                               1259
#
#                                           HC02_VC114  \
# 0  Margin of Error; CITIZEN, VOTING AGE POPULATIO...
# 1                                                166
# 2                                                 87
# 3                                                272
# 4                                                165
#
#                                           HC03_VC114  \
# 0  Percent; CITIZEN, VOTING AGE POPULATION - Citi...
# 1                                               59.8
# 2                                               50.6
# 3                                               54.6
# 4                                               50.7
#
#                                           HC04_VC114  \
# 0  Percent Margin of Error; CITIZEN, VOTING AGE P...
# 1                                                7.9
# 2                                                4.6
# 3                                                6.9
# 4                                                4.3
#
#                                           HC01_VC115  \
# 0  Estimate; CITIZEN, VOTING AGE POPULATION - Cit...
# 1                                                487
# 2                                                559
# 3                                               1194
# 4                                               1226
#
#                                           HC02_VC115  \
# 0  Margin of Error; CITIZEN, VOTING AGE POPULATIO...
# 1                                                125
# 2                                                 91
# 3                                                230
# 4                                                176
#
#                                           HC03_VC115  \
# 0  Percent; CITIZEN, VOTING AGE POPULATION - Citi...
# 1                                               40.2
# 2                                               49.4
# 3                                               45.4
# 4                                               49.3
#
#                                           HC04_VC115
# 0  Percent Margin of Error; CITIZEN, VOTING AGE P...
# 1                                                7.9
# 2                                                4.6
# 3                                                6.9
# 4                                                4.3
#
# [5 rows x 359 columns]

# %%
SLCo_pop = SLCo_pop_all.iloc[1:,1:4]

# %%
SLCo_pop.head()
# Out:
#        GEO.id2                             GEO.display-label HC01_VC03
# 1  49035100100     Census Tract 1001, Salt Lake County, Utah      1690
# 2  49035100200     Census Tract 1002, Salt Lake County, Utah      1405
# 3  49035100306  Census Tract 1003.06, Salt Lake County, Utah      5219
# 4  49035100307  Census Tract 1003.07, Salt Lake County, Utah      5487
# 5  49035100308  Census Tract 1003.08, Salt Lake County, Utah      4274

# %%
SLCo_pop = SLCo_pop.set_axis(['GEOID','Geo_Label','tot_pop'], inplace=False, axis=1)

# %%
SLCo_pop.head()
# Out:
#          GEOID                                     Geo_Label tot_pop
# 1  49035100100     Census Tract 1001, Salt Lake County, Utah    1690
# 2  49035100200     Census Tract 1002, Salt Lake County, Utah    1405
# 3  49035100306  Census Tract 1003.06, Salt Lake County, Utah    5219
# 4  49035100307  Census Tract 1003.07, Salt Lake County, Utah    5487
# 5  49035100308  Census Tract 1003.08, Salt Lake County, Utah    4274

# %%
SLCo_pop.to_csv('SLCo_pop.csv')
