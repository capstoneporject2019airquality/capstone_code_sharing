# %%
import pandas as pd

# %%
data = pd.read_csv('test_data_clean_uak211.csv')

# %%
repeat = pd.DataFrame(data.groupby(['vin'])['test_result'].count()).reset_index()
# repeat = repeat.loc[repeat['count'] >= 2]

# %%
data.head()
# Out:
#    Unnamed: 0        date  station_id test_type test_result  \
# 0           1  01/01/2017       456.0     OBDII        Pass
# 1           2  01/01/2017      1115.0     OBDII        Pass
# 2           3  01/01/2017      1109.0     OBDII        Pass
# 3           4  01/01/2017      1115.0     OBDII        Pass
# 4           5  01/01/2017      1115.0      Idle        Fail
#
#                  vin  model_year   vehicle_type vehicle_class  \
# 0  5N1AN08W97C530793      2007.0          Truck          LDT1
# 1  WBANB53537CP05224      2007.0  Passenger Car           LDV
# 2  JN8AZ28R49T111532      2009.0  Passenger Car          LDT1
# 3  1N6AA07C18N350248      2008.0          Truck          LDT1
# 4  1J4GZ88S5PC113745      1993.0  Passenger Car           LDV
#
#    gross_vehicle_weight_rating
# 0                       5400.0
# 1                       5026.0
# 2                       3848.0
# 3                       7200.0
# 4                       5500.0

# %%
station_stat = pd.DataFrame(data.groupby(['station_id','test_result'])['test_type'].count()).reset_index()

# %%
station_stat.head(10)
# Out:
#    station_id test_result  test_type
# 0         1.0        Fail        883
# 1         1.0        Pass       1749
# 2         1.0      Reject        301
# 3         2.0        Fail         42
# 4         2.0        Pass       1838
# 5         2.0      Reject         81
# 6        11.0        Fail         23
# 7        11.0        Pass        746
# 8        11.0      Reject         28
# 9        24.0        Fail         68

# %%
station_stat = station_stat.pivot(index='station_id', columns='test_result')['test_type'].reset_index()
station_stat.head()
# Out:
# test_result  station_id   Fail    Pass  Reject
# 0                   1.0  883.0  1749.0   301.0
# 1                   2.0   42.0  1838.0    81.0
# 2                  11.0   23.0   746.0    28.0
# 3                  24.0   68.0  1514.0    53.0
# 4                  28.0   66.0  1061.0    40.0

# %%
station_stat.index.names = ['index']

# %%
station_stat['Total'] = station_stat['Fail'] + station_stat['Pass'] + station_stat['Reject']
station_stat['Fail_ratio'] = station_stat['Fail'] / station_stat['Total']
station_stat['Pass_ratio'] = station_stat['Pass'] / station_stat['Total']
station_stat['Rej_ratio'] = station_stat['Reject'] / station_stat['Total']
station_stat.head()
# Out:
# test_result  station_id   Fail    Pass  Reject   Total  Fail_ratio  \
# index
# 0                   1.0  883.0  1749.0   301.0  2933.0    0.301057
# 1                   2.0   42.0  1838.0    81.0  1961.0    0.021418
# 2                  11.0   23.0   746.0    28.0   797.0    0.028858
# 3                  24.0   68.0  1514.0    53.0  1635.0    0.041590
# 4                  28.0   66.0  1061.0    40.0  1167.0    0.056555
#
# test_result  Pass_ratio  Rej_ratio
# index
# 0              0.596318   0.102625
# 1              0.937277   0.041305
# 2              0.936010   0.035132
# 3              0.925994   0.032416
# 4              0.909169   0.034276

# %%
station_stat.to_csv('station_stat.csv')

# %% [markdown]
# ## Task 5:
# Stat: Link two datasets, calculate:
# avg test cost
# #of tests per facility
# total test cost (# of tests per facility X price)

# %%
price = pd.read_csv('verified_avg_fee_by_station_jx.csv')

# %%
price.head()
# Out:
#    No.  Station Id Avg. Test Fees             Station Name  \
# 0  1.0         2.0            $25  KEN GARFF MERCEDES BENZ
# 1  2.0        24.0            $39   OLYMPUS HILLS SINCLAIR
# 2  3.0        28.0            $31            UNION SERVICE
# 3  4.0        38.0            $30   LARRY H. MILLER TOYOTA
# 4  5.0        46.0            $35         QUALITY TIRE CO.
#
#                    Address            City      ZIP   Phone Number Price Tax  \
# 0          575 SOUTH STATE  SALT LAKE CITY  84111.0   855-780-1053    25   0
# 1  3905 SOUTH WASATCH BLVD  SALT LAKE CITY  84124.0  801- 272-2081    39   0
# 2      997 EAST 7220 SOUTH         MIDVALE  84047.0   801-255-4122    Na  Na
# 3          5650 S STATE ST          MURRAY  84107.0   801-264-3850    30   0
# 4     1335 WEST 2100 SOUTH  SALT LAKE CITY  84119.0   801-972-1944    Na  Na
#
#   On the Spot Registration Registration/Sticker Fee   Service Type  \
# 0                       Na                       Na  TestAndRepair
# 1                       Na                       Na  TestAndRepair
# 2                       Na                       Na             Na
# 3                      Yes                        5  TestAndRepair
# 4                       Na                       Na             Na
#
#   Detailed Information
# 0                   Na
# 1                   Na
# 2                   Na
# 3                   Na
# 4                   Na

# %%
data.head()
# Out:
#    Unnamed: 0        date  station_id test_type test_result  \
# 0           1  01/01/2017       456.0     OBDII        Pass
# 1           2  01/01/2017      1115.0     OBDII        Pass
# 2           3  01/01/2017      1109.0     OBDII        Pass
# 3           4  01/01/2017      1115.0     OBDII        Pass
# 4           5  01/01/2017      1115.0      Idle        Fail
#
#                  vin  model_year   vehicle_type vehicle_class  \
# 0  5N1AN08W97C530793      2007.0          Truck          LDT1
# 1  WBANB53537CP05224      2007.0  Passenger Car           LDV
# 2  JN8AZ28R49T111532      2009.0  Passenger Car          LDT1
# 3  1N6AA07C18N350248      2008.0          Truck          LDT1
# 4  1J4GZ88S5PC113745      1993.0  Passenger Car           LDV
#
#    gross_vehicle_weight_rating
# 0                       5400.0
# 1                       5026.0
# 2                       3848.0
# 3                       7200.0
# 4                       5500.0

# %%
total = pd.merge(data, price, left_on = 'station_id', right_on = 'Station Id', how='right')

# %%
total.head()
# Out:
#    Unnamed: 0        date  station_id test_type test_result  \
# 0         1.0  01/01/2017       456.0     OBDII        Pass
# 1      1838.0  01/03/2017       456.0     OBDII        Pass
# 2      2033.0  01/03/2017       456.0     OBDII        Pass
# 3      2160.0  01/03/2017       456.0     OBDII        Pass
# 4      2204.0  01/03/2017       456.0     OBDII        Pass
#
#                  vin  model_year   vehicle_type vehicle_class  \
# 0  5N1AN08W97C530793      2007.0          Truck          LDT1
# 1  1J8FF28W88D530503      2008.0          Truck          LDT1
# 2  1Z7HT28K57S217557      2007.0          Truck          LDT1
# 3  1GNFK13007R222363      2007.0          Truck          LDT1
# 4  1G6KD54Y7WU729949      1998.0  Passenger Car           LDV
#
#    gross_vehicle_weight_rating  ...               Address         City  \
# 0                       5400.0  ...  8131 So. REDWOOD RD.  WEST JORDAN
# 1                       3575.0  ...  8131 So. REDWOOD RD.  WEST JORDAN
# 2                       5070.0  ...  8131 So. REDWOOD RD.  WEST JORDAN
# 3                       7300.0  ...  8131 So. REDWOOD RD.  WEST JORDAN
# 4                       5161.0  ...  8131 So. REDWOOD RD.  WEST JORDAN
#
#        ZIP   Phone Number Price Tax  On the Spot Registration  \
# 0  84088.0  801- 568-2400    35   0                       Yes
# 1  84088.0  801- 568-2400    35   0                       Yes
# 2  84088.0  801- 568-2400    35   0                       Yes
# 3  84088.0  801- 568-2400    35   0                       Yes
# 4  84088.0  801- 568-2400    35   0                       Yes
#
#   Registration/Sticker Fee   Service Type Detailed Information
# 0                        8  TestAndRepair                   Na
# 1                        8  TestAndRepair                   Na
# 2                        8  TestAndRepair                   Na
# 3                        8  TestAndRepair                   Na
# 4                        8  TestAndRepair                   Na
#
# [5 rows x 24 columns]

# %%
total_cleaned = total.dropna(subset=['Price'])

# %%
# total_cleaned['Price'].mean()
